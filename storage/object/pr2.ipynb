# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('Diwali_sales.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'User_ID', 'Cust_name', 'Product_ID', 'Gender',
#        'Age Group', 'Age', 'Marital_Status', 'State', 'Zone', 'Occupation',
#        'Product_Category', 'Orders', 'Amount', 'age_group'],
#       dtype='object')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    Unnamed: 0  User_ID  Cust_name Product_ID Gender Age Group  Age  \
# 0           0  1002903  Sanskriti  P00125942      F     26-35   28
# 1           1  1000732     Kartik  P00110942      F     26-35   35
# 2           2  1001990      Bindu  P00118542      F     26-35   35
# 3           3  1001425     Sudevi  P00237842      M      0-17   16
# 4           4  1000588       Joni  P00057942      M     26-35   28
#
#    Marital_Status           State      Zone       Occupation Product_Category  \
# 0               0     Maharashtra   Western       Healthcare             Auto
# 1               1  Andhra Pradesh  Southern             Govt             Auto
# 2               1   Uttar Pradesh   Central       Automobile             Auto
# 3               0       Karnataka  Southern     Construction             Auto
# 4               1         Gujarat   Western  Food Processing             Auto
#
#    Orders   Amount age_group
# 0       1  23952.0     19-30
# 1       3  23934.0     31-40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        11251 non-null  int64
#  1   User_ID           11251 non-null  int64
#  2   Cust_name         11251 non-null  object
#  3   Product_ID        11251 non-null  object
#  4   Gender            11251 non-null  object
#  5   Age Group         11251 non-null  object
#  6   Age               11251 non-null  int64
#  7   Marital_Status    11251 non-null  int64
#  8   State             11251 non-null  object
#  9   Zone              11251 non-null  object
#  10  Occupation        11251 non-null  object
#  11  Product_Category  11251 non-null  object
#  12  Orders            11251 non-null  int64
#  13  Amount            11239 non-null  float64
#  14  age_group         11115 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 1.3+ MB

# %%
df.drop(['Marital_Status', 'Unnamed: 0'],axis=1 ,inplace=True)
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'age_group'],
#       dtype='object')

# %%
pd.isnull(df).sum()
# Out:
# User_ID               0
# Cust_name             0
# Product_ID            0
# Gender                0
# Age Group             0
# Age                   0
# State                 0
# Zone                  0
# Occupation            0
# Product_Category      0
# Orders                0
# Amount               12
# age_group           136
# dtype: int64

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11103 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11103 non-null  int64
#  1   Cust_name         11103 non-null  object
#  2   Product_ID        11103 non-null  object
#  3   Gender            11103 non-null  object
#  4   Age Group         11103 non-null  object
#  5   Age               11103 non-null  int64
#  6   State             11103 non-null  object
#  7   Zone              11103 non-null  object
#  8   Occupation        11103 non-null  object
#  9   Product_Category  11103 non-null  object
#  10  Orders            11103 non-null  int64
#  11  Amount            11103 non-null  float64
#  12  age_group         11103 non-null  object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 1.2+ MB

# %%
df['Amount']=df['Amount'].astype('int')
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.describe()
# Out:
#             User_ID           Age        Orders        Amount
# count  1.110300e+04  11103.000000  11103.000000  11103.000000
# mean   1.003003e+06     34.784473      2.489237   9449.739350
# std    1.717276e+03     11.496090      1.114926   5218.772198
# min    1.000001e+06     12.000000      1.000000    188.000000
# 25%    1.001490e+06     27.000000      2.000000   5443.000000
# 50%    1.003067e+06     33.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000      3.000000  12671.000000
# max    1.006040e+06     80.000000      4.000000  23952.000000

# %%
df.describe(include='all')
# Out:
#              User_ID Cust_name Product_ID Gender Age Group           Age  \
# count   1.110300e+04     11103      11103  11103     11103  11103.000000
# unique           NaN      1250       2346      2         7           NaN
# top              NaN  Vishakha  P00265242      F     26-35           NaN
# freq             NaN        42         52   7745      4541           NaN
# mean    1.003003e+06       NaN        NaN    NaN       NaN     34.784473
# std     1.717276e+03       NaN        NaN    NaN       NaN     11.496090
# min     1.000001e+06       NaN        NaN    NaN       NaN     12.000000
# 25%     1.001490e+06       NaN        NaN    NaN       NaN     27.000000
# 50%     1.003067e+06       NaN        NaN    NaN       NaN     33.000000
# 75%     1.004430e+06       NaN        NaN    NaN       NaN     43.000000
# max     1.006040e+06       NaN        NaN    NaN       NaN     80.000000
#
#                 State     Zone Occupation    Product_Category        Orders  \
# ...

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11103.000000  11103.000000  11103.000000
# mean      34.784473      2.489237   9449.739350
# std       11.496090      1.114926   5218.772198
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12671.000000
# max       80.000000      4.000000  23952.000000

# %%
ax=sns.countplot(x='Gender',data=df, color='purple')
for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_gen=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Gender',y='Amount',data=sales_gen,color="#ff8851")
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
ax=sns.countplot(x='Age Group',hue='Gender', data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_age=df.groupby(['Age Group'],as_index=False) ['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.barplot(x='Age Group',y='Amount',data=sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
sales_states=df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',
ascending=False).head(10)
sns.barplot(x='State',y='Orders',data=sales_states)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
sales_state=df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',
ascending=False).head(10)
sns.barplot(x='State',y='Amount',data=sales_state)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
sales_state=df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Occupation',y='Amount',data=sales_state,color="#0FDBFF")
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>
